# %% [markdown]
# ## Naan Mudhalvan
# PROFESSIONAL READINESS FOR INNOVATION, EMPLOYABILITY AND ENTREPRENEURSHIP

# %% [markdown]
# ### Assignment 1
# Given Task
# 1. Download the dataset
# 2. Load the dataset
# 3. Perform the below visualizations
#     * Univariate analysis
#     * Bi-Variate analysis
#     * Multi-Variate analysis
# 4. Perform descriptive statistics on the dataset
# 5. Handle the missing values.

# %% [markdown]
# ### Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Loading dataset

# %%
df = pd.read_csv("House Price India.csv")

# %%
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area
# 0  6762810145  42491                   5                 2.50         3650  \
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views
# 0      9050               2.0                   0                4  \
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code
# ...

# %%
df.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %%
df.describe().transpose()
# Out:
#                                          count          mean            std
# id                                     14620.0  6.762821e+09    6237.574799  \
# Date                                   14620.0  4.260454e+04      67.347991
# number of bedrooms                     14620.0  3.379343e+00       0.938719
# number of bathrooms                    14620.0  2.129583e+00       0.769934
# living area                            14620.0  2.098263e+03     928.275721
# lot area                               14620.0  1.509328e+04   37919.621304
# number of floors                       14620.0  1.502360e+00       0.540239
# waterfront present                     14620.0  7.660739e-03       0.087193
# number of views                        14620.0  2.331053e-01       0.766259
# condition of the house                 14620.0  3.430506e+00       0.664151
# grade of the house                     14620.0  7.682421e+00       1.175033
# ...

# %%
plt.figure(figsize=(12,8))
sns.displot(df['Price'])

# %%
sns.countplot(data=df,x='number of bedrooms')
# Out:
# <Axes: xlabel='number of bedrooms', ylabel='count'>

# %%
df.corr()['Price'].sort_values()
# Out:
# id                                      -0.773114
# Postal Code                             -0.115908
# Date                                    -0.027919
# Distance from the airport                0.003804
# Number of schools nearby                 0.009890
# Longitude                                0.024414
# condition of the house                   0.041376
# Built Year                               0.050307
# lot_area_renov                           0.075535
# lot area                                 0.081992
# Renovation Year                          0.133173
# number of floors                         0.262732
# waterfront present                       0.263687
# Lattitude                                0.297490
# number of bedrooms                       0.308460
# Area of the basement                     0.330202
# number of views                          0.395973
# number of bathrooms                      0.531735
# living_area_renov                        0.584924
# ...

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='Price',y='living area',data=df)
# Out:
# <Axes: xlabel='Price', ylabel='living area'>

# %%
sns.boxplot(x='number of bedrooms',y='Price',data=df)
# Out:
# <Axes: xlabel='number of bedrooms', ylabel='Price'>

# %%
df.columns
# Out:
# Index(['id', 'Date', 'number of bedrooms', 'number of bathrooms',
#        'living area', 'lot area', 'number of floors', 'waterfront present',
#        'number of views', 'condition of the house', 'grade of the house',
#        'Area of the house(excluding basement)', 'Area of the basement',
#        'Built Year', 'Renovation Year', 'Postal Code', 'Lattitude',
#        'Longitude', 'living_area_renov', 'lot_area_renov',
#        'Number of schools nearby', 'Distance from the airport', 'Price'],
#       dtype='object')

# %%
sns.scatterplot(x='Price',y='Longitude',data=df)
# Out:
# <Axes: xlabel='Price', ylabel='Longitude'>

# %%
sns.scatterplot(x='Price',y='Lattitude',data=df)
# Out:
# <Axes: xlabel='Price', ylabel='Lattitude'>

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='Longitude',y='Lattitude',data=df,hue='Price')
# Out:
# <Axes: xlabel='Longitude', ylabel='Lattitude'>

# %%
df.sort_values('Price',ascending=False).head(20)
# Out:
#                id   Date  number of bedrooms  number of bathrooms
# 10503  6762810020  42655                   6                 8.00  \
# 2424   6762810021  42531                   5                 4.50
# 9171   6762810022  42631                   6                 7.75
# 6244   6762810023  42585                   5                 5.75
# 10915  6762810026  42662                   5                 5.25
# 2794   6762810027  42537                   5                 6.75
# 2907   6762810029  42538                   4                 3.00
# 10566  6762810031  42656                   4                 5.50
# 12442  6762810032  42687                   4                 4.25
# 8691   6762810034  42623                   3                 4.25
# 3946   6762810033  42551                   5                 5.50
# 1697   6762810035  42519                   4                 3.50
# 8692   6762810038  42623                   4                 3.25
# ...

# %%
len(df)*0.01
# Out:
# 146.20000000000002

# %%
top_one_perc = df.sort_values('Price',ascending=False).iloc[146:]

# %%
sns.scatterplot(x='Longitude',y='Lattitude',data=top_one_perc,palette='RdYlGn',hue='Price')
# Out:
# <Axes: xlabel='Longitude', ylabel='Lattitude'>
